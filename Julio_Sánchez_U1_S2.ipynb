# %%
x=5
y=6
suma=x+y
resta=x-y
multiplicacion= x*y
division= x/y
potencia=x**y

print ("**************RESULTADOS***********")
print("La suma es: ", suma)
print("La resta es: ", resta)
print("La multiplicacion es:", multiplicacion)
print("La potenia es:",potencia)
# Out:
# **************RESULTADOS***********
# La suma es:  11
# La resta es:  -1
# La multiplicacion es: 30
# La potenia es: 15625

# %%
def mostrar_datos():
    # Variables locales
    nombre_estudiante = "Julio David Sánchez Sagué"
    carrera = "Ciencia de Datos e IA"
    semestre = "Primero"

    print(nombre_estudiante)
    print(carrera)
    print(semestre)

mostrar_datos()
# Out:
# Julio David Sánchez Sagué
# Ciencia de Datos e IA
# Primero

# %%
#Crear variable local
def mostrar_datos():
  #variable locales
  nombre_estudiante = "Erick Zambrano"
  carrera= "Ciencias de datos e inteligencia artificial"
  semestre= "Primero C"
#imprimir los datos
print("nombre de la estudiante:", nombre_estudiante)
print("Carrera es:", carrera)
print("semestre es:", semestre)
mostrar_datos()
# Out:
# nombre de la estudiante: Julio David Sánchez Sagué
# Carrera es: Ciencia de Datos e IA
# semestre es: Primero

# %%
#Decalro Variables
nota= 8
asistencia= 90

#Aplicamos condicionales

aprueba=(nota>=7) and (asistencia>=80)

print("El estudiante aprueba", aprueba)
# Out:
# El estudiante aprueba True

# %%
edad = int(input(print("Ingrese la edad de la persona: ")))
if edad <= 12:
  print("La persona es un niño")
elif edad <= 18:
  print("La persona es un adolescente")
else:
  print("La persona es un adulto")
# Out:
# Ingrese la edad de la persona:
# None15
# La persona es un adolescente

# %%
#Sacando paridad
numero = 7
if numero % 2 == 0:
  print("El número es par")
else:
  print("El número es impar")
# Out:
# El número es impar

# %%
# Validando nota
nota = int(input(print("Ingrese su nota: ")))
if nota >= 9:
  print("Excelente")
elif nota >= 7:
  print("Aprobado")
else:
  print ("Reprobado")
# Out:
# Ingrese su nota:
# None9
# Excelente
